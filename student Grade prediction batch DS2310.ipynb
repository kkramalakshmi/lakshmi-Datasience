# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Grades/Grades.csv')
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.tail(5)
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# ...

# %%
df.shape
# Out:
# (571, 43)

# %%
df.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# ...

# %% [markdown]
# above data set contain object type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %% [markdown]
# it contain null values we can fill null values

# %% [markdown]
# visualisation of null values

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
df.nunique().to_frame('No.of unique values')
# Out:
#            No.of unique values
# Seat No.                   571
# PH-121                      13
# HS-101                      12
# CY-105                      13
# HS-105/12                   13
# MT-111                      13
# CS-105                      11
# CS-106                      13
# EL-102                      13
# EE-119                      12
# ME-107                      13
# CS-107                      14
# HS-205/20                   13
# MT-222                      14
# EE-222                      13
# MT-224                      14
# CS-210                      14
# CS-211                      14
# CS-203                      13
# CS-214                      13
# EE-217                      13
# CS-212                      12
# CS-215                      14
# MT-331                      12
# EF-303                      12
# HS-304                      14
# CS-301                      12
# CS-302                      11
# TC-383                      12
# ...

# %%
# check value counts in each column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# CS-97001    1
# CS-97384    1
# CS-97378    1
# CS-97379    1
# CS-97380    1
#            ..
# CS-97185    1
# CS-97184    1
# CS-97183    1
# CS-97182    1
# CS-97571    1
# Name: Seat No., Length: 571, dtype: int64
#
#
# A-    112
# A     111
# B+     61
# B      57
# B-     56
# D      44
# C      33
# C+     31
# D+     22
# A+     22
# C-     19
# WU      2
# F       1
# Name: PH-121, dtype: int64
#
#
# A-    82
# B-    78
# C     68
# B     63
# B+    59
# C-    50
# C+    47
# D     45
# A     38
# D+    36
# A+     4
# F      1
# Name: HS-101, dtype: int64
#
#
# A     177
# A-    120
# B+     50
# B      49
# B-     42
# D      31
# A+     31
# C      19
# C+     17
# C-     16
# D+     14
# WU      3
# F       1
# Name: CY-105, dtype: int64
#
#
# A     96
# A-    75
# B+    70
# B     57
# D     45
# C     41
# B-    40
# C+    39
# C-    36
# D+    34
# A+    34
# WU     2
# F      1
# Name: HS-105/12, dtype: int64
#
#
# A-    105
# A     100
# B-     70
# B+     62
# ...

# %% [markdown]
# Fill null values

# %%
df['CY-105'].fillna('A',inplace=True)
df['HS-105/12'].fillna('A',inplace=True)
df['MT-111'].fillna('A',inplace=True)
df['CS-106'].fillna('A',inplace=True)
df['EL-102'].fillna('A',inplace=True)
df['EE-119'].fillna('A',inplace=True) 
df['ME-107'].fillna('A',inplace=True) 
df['CS-107'].fillna('A',inplace=True)
df['HS-205/20'].fillna('A',inplace=True) 
df['MT-222'].fillna('A',inplace=True)      
df['EE-222'].fillna('A',inplace=True) 
df['MT-224'].fillna('A',inplace=True)         
df['CS-210'].fillna('A',inplace=True)         
df['CS-211'].fillna('A',inplace=True)         
df['CS-203'].fillna('A',inplace=True)         
df['CS-214'].fillna('A',inplace=True)         
df['EE-217'].fillna('A',inplace=True)         
df['CS-212'].fillna('A',inplace=True)         
df['CS-215'].fillna('A',inplace=True)         
df['MT-331'].fillna('A',inplace=True)         
df['EF-303'].fillna('A',inplace=True)        
df['HS-304'].fillna('A',inplace=True)        
df['CS-301'].fillna('A',inplace=True)        
df['CS-302'].fillna('A',inplace=True)        
df['TC-383'].fillna('A',inplace=True)        
df['MT-442'].fillna('A',inplace=True)        
df['EL-332'].fillna('A',inplace=True)         
df['CS-318'].fillna('A',inplace=True)         
df['CS-306'].fillna('A',inplace=True)         
df['CS-312'].fillna('A',inplace=True)        
df['CS-317'].fillna('A',inplace=True)        
df['CS-403'].fillna('A',inplace=True)        
df['CS-421'].fillna('A',inplace=True)        
df['CS-414'].fillna('A',inplace=True)        
df['CS-419'].fillna('A',inplace=True)        
df['CS-423'].fillna('A',inplace=True)        
df['CS-412'].fillna('A',inplace=True)
df['CS-406'].fillna('A',inplace=True)

# %%
# converting categorical data to numerical data
clean_data = {'PH-121':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12},
              'HS-101':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'CY-105':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'HS-105/12':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'MT-111':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12},
              'CS-105':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'I':14}, 
              'CS-106':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'EL-102':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'EE-119':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'ME-107':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'CS-107':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13,'I':14}, 
              'HS-205/20':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13},
              'MT-222':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13}, 
              'EE-222':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13}, 
              'MT-224':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13}, 
              'CS-210':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13},
              'CS-211':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13}, 
              'CS-203':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13,'I':14}, 
              'CS-214':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13,'I':14},
              'EE-217':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12},
              'CS-212':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'CS-215':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13}, 
              'MT-331':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12},
              'EF-303':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'HS-304':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13}, 
              'CS-301':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12},
              'CS-302':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'TC-383':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'MT-442':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'EL-332':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'CS-318':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13}, 
              'CS-306':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'CS-312':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13},
              'CS-317':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'CS-403':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12}, 
              'CS-421':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13}, 
              'CS-406':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13},
              'CS-414':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13},
              'CS-419':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12},
              'CS-423':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12},
              'CS-412':{'A':0,'A-':1,'A+':2,'B':3,'B-':4,'B+':5,'C':6,'C-':7,'C+':8,'D':9,'D+':10,'F':11,'WU':12,'W':13}}
               
df = df.copy()
df.replace(clean_data, inplace=True)

# %%
df
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0    CS-97001       4      10       7          6       7      10       9
# 1    CS-97002       0       9      10          9       4       6       9
# 2    CS-97003       0       3       0          4       5       0       4
# 3    CS-97004       9       8      10          9       9       1      10
# 4    CS-97005       1       1       1          5       0       0       1
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566  CS-97567       3       0       0          1       2       0       1
# 567  CS-97568       2       0       0          0       0       0       0
# 568  CS-97569       3       0       1          5       0       0       0
# 569  CS-97570       0       5       9          0       9      10       4
# 570  CS-97571       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0    CS-97001       4      10       7          6       7      10       9
# 1    CS-97002       0       9      10          9       4       6       9
# 2    CS-97003       0       3       0          4       5       0       4
# 3    CS-97004       9       8      10          9       9       1      10
# 4    CS-97005       1       1       1          5       0       0       1
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566  CS-97567       3       0       0          1       2       0       1
# 567  CS-97568       2       0       0          0       0       0       0
# 568  CS-97569       3       0       1          5       0       0       0
# 569  CS-97570       0       5       9          0       9      10       4
# 570  CS-97571       6       9       9          6       6      10       3
#
# ...

# %%
df.dtypes
# Out:
# Seat No.      object
# PH-121         int64
# HS-101         int64
# CY-105         int64
# HS-105/12      int64
# MT-111         int64
# CS-105         int64
# CS-106         int64
# EL-102         int64
# EE-119         int64
# ME-107         int64
# CS-107         int64
# HS-205/20      int64
# MT-222         int64
# EE-222         int64
# MT-224         int64
# CS-210         int64
# CS-211         int64
# CS-203         int64
# CS-214         int64
# EE-217         int64
# CS-212         int64
# CS-215         int64
# MT-331         int64
# EF-303         int64
# HS-304         int64
# CS-301         int64
# CS-302         int64
# TC-383         int64
# MT-442         int64
# EL-332         int64
# CS-318         int64
# CS-306         int64
# CS-312         int64
# CS-317         int64
# CS-403         int64
# CS-421         int64
# CS-406         int64
# CS-414         int64
# CS-419         int64
# CS-423         int64
# CS-412         int64
# CGPA         float64
# ...

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    int64
#  2   HS-101     571 non-null    int64
#  3   CY-105     571 non-null    int64
#  4   HS-105/12  571 non-null    int64
#  5   MT-111     571 non-null    int64
#  6   CS-105     571 non-null    int64
#  7   CS-106     571 non-null    int64
#  8   EL-102     571 non-null    int64
#  9   EE-119     571 non-null    int64
#  10  ME-107     571 non-null    int64
#  11  CS-107     571 non-null    int64
#  12  HS-205/20  571 non-null    int64
#  13  MT-222     571 non-null    int64
#  14  EE-222     571 non-null    int64
#  15  MT-224     571 non-null    int64
#  16  CS-210     571 non-null    int64
#  17  CS-211     571 non-null    int64
#  18  CS-203     571 non-null    int64
#  19  CS-214     571 non-null    int64
# ...

# %% [markdown]
# no nullvalues maximum dataset contain A grade so NAN can replace by' A'

# %%
df.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     3.653240    4.896673    2.758319    4.227671    3.721541    2.719790
# std      3.186964    2.952520    3.044307    3.270925    3.088384    2.798235
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    3.000000    0.000000    1.000000    1.000000    0.000000
# 50%      3.000000    5.000000    1.000000    4.000000    4.000000    2.000000
# 75%      6.000000    7.000000    5.000000    7.000000    6.000000    5.000000
# max     12.000000   11.000000   12.000000   12.000000   12.000000   10.000000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-312  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     4.026270    3.852890    3.733800    4.649737  ...    4.105079
# ...

# %% [markdown]
# the dataset contain huge gap between max and 75%

# %%
df.corr()
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.343163  0.507242   0.440784  0.398709  0.546413
# HS-101     0.343163  1.000000  0.269889   0.428254  0.369514  0.346439
# CY-105     0.507242  0.269889  1.000000   0.448109  0.475557  0.524612
# HS-105/12  0.440784  0.428254  0.448109   1.000000  0.427956  0.428672
# MT-111     0.398709  0.369514  0.475557   0.427956  1.000000  0.338299
# CS-105     0.546413  0.346439  0.524612   0.428672  0.338299  1.000000
# CS-106     0.264773  0.274606  0.330702   0.449369  0.449897  0.211378
# EL-102     0.401502  0.303069  0.389947   0.324052  0.477142  0.318614
# EE-119     0.522185  0.270804  0.392038   0.322084  0.340548  0.415532
# ME-107     0.474107  0.285943  0.421754   0.291035  0.421595  0.412951
# CS-107     0.421450  0.445748  0.452254   0.479853  0.443203  0.445897
# HS-205/20  0.259907  0.168902  0.213670   0.145580  0.271778  0.167024
# ...

# %% [markdown]
# above data set contain positive values

# %%
plt.figure(figsize=(18,40))
sns.heatmap(df.corr(),annot=True)
plt.xlabel('Figure')
plt.ylabel('Feaatures_Name')
plt.title('Discriptive_Graph')
plt.show()

# %%
df.skew()
# Out:
# PH-121       0.550770
# HS-101       0.012716
# CY-105       1.019752
# HS-105/12    0.275083
# MT-111       0.503652
# CS-105       0.940475
# CS-106       0.468477
# EL-102       0.470047
# EE-119       0.478156
# ME-107       0.078700
# CS-107       0.406227
# HS-205/20    0.857094
# MT-222       0.190871
# EE-222       0.742960
# MT-224       0.387524
# CS-210       0.672731
# CS-211       0.096369
# CS-203       0.255679
# CS-214       0.046175
# EE-217       0.705737
# CS-212       0.293658
# CS-215       0.150958
# MT-331       0.615582
# EF-303       0.140543
# HS-304       0.375275
# CS-301       0.342921
# CS-302       0.551446
# TC-383       0.292641
# MT-442       0.839976
# EL-332       0.414558
# CS-318       0.224720
# CS-306       0.376452
# CS-312       0.424526
# CS-317       0.129781
# CS-403       0.641380
# CS-421       0.067582
# CS-406       1.334023
# CS-414       1.349707
# CS-419       0.425656
# CS-423       0.452692
# CS-412       1.149968
# ...

# %% [markdown]
# gives range +/- 0.5 give information about outliers

# %% [markdown]
# # Visualisation

# %%
plt.figure(figsize=(8,6))
sns.countplot(x ='CGPA', data = df)
plt.xlabel('CGPA')
plt.ylabel('Count of Rows in the dataset')
plt.show()

# %%
Index=0
labels = df['CGPA']
features = df.drop('CGPA', axis=1)

for col in features.items():
    plt.figure(figsize=(10,5))
    sns.scatterplot(x=labels, y=col[Index], data=df, color="red")
plt.tight_layout()
plt.show()

# %%
Index=0
labels = df['CGPA']
features = df.drop('CGPA', axis=1)

for col in features.items():
    plt.figure(figsize=(10,5))
    sns.barplot(x=labels, y=col[Index], data=df, color="red")
plt.tight_layout()
plt.show()

# %%
X=df.drop(columns=['CGPA','Seat No.'])
Y=df['CGPA']

# %%
plt.figure(figsize=(20,25),facecolor='red')
plotnumber=1
for column in X:
    if plotnumber<=43 :
        ax=plt.subplot(8,8,plotnumber)
        sns.distplot(X[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %% [markdown]
# there is may or may not contain outliers

# %%
plt.figure(figsize=(20,25))
plotnumber=1
for column in X:
    if plotnumber<=43 :
        ax=plt.subplot(8,8,plotnumber)
        sns.stripplot(X[column])
        
    plotnumber+=1
plt.show()

# %% [markdown]
# all features have same importance

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
X
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         4      10       7          6       7      10       9       7
# 1         0       9      10          9       4       6       9       0
# 2         0       3       0          4       5       0       4       5
# 3         9       8      10          9       9       1      10       7
# 4         1       1       1          5       0       0       1       5
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       3       0       0          1       2       0       1       1
# 567       2       0       0          0       0       0       0       1
# 568       3       0       1          5       0       0       0       0
# 569       0       5       9          0       9      10       4       7
# 570       6       9       9          6       6      10       3       8
#
#      EE-119  ME-107  ...  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  \
# ...

# %%
Y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# 570    1.753
# Name: CGPA, Length: 571, dtype: float64

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X
# Out:
#        PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105    CS-106  \
# 0    0.108901  1.729980  1.394538   0.542318  1.062476  2.603997  1.684743
# 1   -1.147312  1.390990  2.380848   1.460294  0.090242  1.173271  1.684743
# 2   -1.147312 -0.642954 -0.906853  -0.069665  0.414320 -0.972819 -0.008898
# 3    1.679168  1.051999  2.380848   1.460294  1.710632 -0.615137  2.023471
# 4   -0.833259 -1.320936 -0.578083   0.236327 -1.206069 -0.972819 -1.025083
# ..        ...       ...       ...        ...       ...       ...       ...
# 566 -0.205152 -1.659926 -0.906853  -0.987641 -0.557913 -0.972819 -1.025083
# 567 -0.519206 -1.659926 -0.906853  -1.293633 -1.206069 -0.972819 -1.363811
# 568 -0.205152 -1.659926 -0.578083   0.236327 -1.206069 -0.972819 -1.363811
# 569 -1.147312  0.035027  2.052078  -1.293633  1.710632  2.603997 -0.008898
# 570  0.737008  1.390990  2.052078   0.542318  0.738398  2.603997 -0.347627
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, confusion_matrix,mean_absolute_error
from sklearn.model_selection import cross_val_score, RandomizedSearchCV, GridSearchCV

# %% [markdown]
# # Find Best random state

# %%
maxAccu=0
maxRS=0
for i in range(1,250):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=i)
    lr=LinearRegression()
    lr.fit(X_train,Y_train)
    pred=lr.predict(X_test)
    acc=r2_score(Y_test,pred) 
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best r2_score is-",maxAccu,"at randomstate is -",maxRS)
# Out:
# Best r2_score is- 0.9512874891878649 at randomstate is - 72

# %% [markdown]
# # Train Test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.3,random_state=maxRS)

# %%
print('Size of X_train : ', X_train.shape)
print('Size of y_train : ', y_train.shape)
print('Size of X_test : ', X_test.shape)
print('Size of Y_test : ', y_test.shape)
# Out:
# Size of X_train :  (399, 41)
# Size of y_train :  (399,)
# Size of X_test :  (172, 41)
# Size of Y_test :  (172,)

# %%
LR = LinearRegression()
LR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred_LR=LR.predict(X_test)
pred_train=LR.predict(X_train)
print('R2_score',r2_score(y_test,pred_LR))
print('R2_score on training data',r2_score(y_train,pred_train)*100)
print('Mean absolute Error',mean_absolute_error(y_test,pred_LR))
print('Mean Squared Error',mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error',np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score 0.9356400582619888
# R2_score on training data 87.14012488278331
# Mean absolute Error 0.12390662533324868
# Mean Squared Error 0.024808326107380128
# Root Mean Squared Error 0.15750659067918438

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RFR=RandomForestRegressor()
RFR.fit(X_train, y_train)
pred_RFR=RFR.predict(X_test)
pred_train=RFR.predict(X_train)
print('R2_score',r2_score(y_test,pred_RFR))
print('R2_score on training data',r2_score(y_train,pred_train)*100)
print('Mean absolute Error',mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error',mean_squared_error(y_test,pred_RFR))
print('Root Mean Squared Error',np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score 0.9538019419425371
# R2_score on training data 98.14984221825985
# Mean absolute Error 0.09995337209302324
# Mean Squared Error 0.017807606080232553
# Root Mean Squared Error 0.13344514258762868

# %%
from sklearn.neighbors import KNeighborsRegressor as KNN
knn=KNN()
knn.fit(X_train, y_train)
pred_knn=knn.predict(X_test)
pred_train=knn.predict(X_train)
print('R2_score',r2_score(y_test,pred_knn))
print('R2_score on training data',r2_score(y_train,pred_train)*100)
print('Mean absolute Error',mean_absolute_error(y_test,pred_knn))
print('Mean Squared Error',mean_squared_error(y_test,pred_knn))
print('Root Mean Squared Error',np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2_score 0.9552596289957265
# R2_score on training data 87.48433080290118
# Mean absolute Error 0.10710465116279068
# Mean Squared Error 0.01724572279069767
# Root Mean Squared Error 0.13132297129861809

# %%
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import GradientBoostingRegressor
GBR=GradientBoostingRegressor()
GBR.fit(X_train, y_train)
pred_GBR=GBR.predict(X_test)
pred_train=GBR.predict(X_train)
print('R2_score',r2_score(y_test,pred_GBR))
print('R2_score on training data',r2_score(y_train,pred_train)*100)
print('Mean absolute Error',mean_absolute_error(y_test,pred_GBR))
print('Mean Squared Error',mean_squared_error(y_test,pred_GBR))
print('Root Mean Squared Error',np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2_score 0.9724638010209943
# R2_score on training data 99.614835725924
# Mean absolute Error 0.07694677235390494
# Mean Squared Error 0.010614164425593688
# Root Mean Squared Error 0.10302506697689494

# %%
lasso=Lasso()
lasso.fit(X_train, y_train)
pred_lasso=lasso.predict(X_test)
pred_train=lasso.predict(X_train)
print('R2_score',r2_score(y_test,pred_lasso))
print('R2_score on training data',r2_score(y_train,pred_train)*100)
print('Mean absolute Error',mean_absolute_error(y_test,pred_lasso))
print('Mean Squared Error',mean_squared_error(y_test,pred_lasso))
print('Root Mean Squared Error',np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score -0.002069645787602381
# R2_score on training data 0.0
# Mean absolute Error 0.5310373025587224
# Mean Squared Error 0.3862599915985248
# Root Mean Squared Error 0.6214981831015476

# %%
rd=Ridge()
rd.fit(X_train, y_train)
pred_rd=rd.predict(X_test)
pred_train=rd.predict(X_train)
print('R2_score',r2_score(y_test,pred_rd))
print('R2_score on training data',r2_score(y_train,pred_train)*100)
print('Mean absolute Error',mean_absolute_error(y_test,pred_rd))
print('Mean Squared Error',mean_squared_error(y_test,pred_rd))
print('Root Mean Squared Error',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2_score 0.9359339500911483
# R2_score on training data 87.14001757101202
# Mean absolute Error 0.1236117015123647
# Mean Squared Error 0.024695041910079856
# Root Mean Squared Error 0.15714656187801201

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(X_train, y_train)
pred_dtr=dtr.predict(X_test)
pred_train=dtr.predict(X_train)
print('R2_score',r2_score(y_test,pred_dtr))
print('R2_score on training data',r2_score(y_train,pred_train)*100)
print('Mean absolute Error',mean_absolute_error(y_test,pred_dtr))
print('Mean Squared Error',mean_squared_error(y_test,pred_dtr))
print('Root Mean Squared Error',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_score 0.821626201844543
# R2_score on training data 100.0
# Mean absolute Error 0.19711627906976747
# Mean Squared Error 0.06875636046511628
# Root Mean Squared Error 0.2622143406930984

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(X_train, y_train)
pred_svr=svr.predict(X_test)
pred_train=svr.predict(X_train)
print('R2_score',r2_score(y_test,pred_svr))
print('R2_score on training data',r2_score(y_train,pred_train)*100)
print('Mean absolute Error',mean_absolute_error(y_test,pred_svr))
print('Mean Squared Error',mean_squared_error(y_test,pred_svr))
print('Root Mean Squared Error',np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2_score 0.9626444098595729
# R2_score on training data 96.304597458358
# Mean absolute Error 0.09464747985471028
# Mean Squared Error 0.014399168754840876
# Root Mean Squared Error 0.11999653642851896

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(X_train, y_train)
pred_etr=etr.predict(X_test)
pred_train=etr.predict(X_train)
print('R2_score',r2_score(y_test,pred_etr))
print('R2_score on training data',r2_score(y_train,pred_train)*100)
print('Mean absolute Error',mean_absolute_error(y_test,pred_etr))
print('Mean Squared Error',mean_squared_error(y_test,pred_etr))
print('Root Mean Squared Error',np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2_score 0.9552510021074069
# R2_score on training data 100.0
# Mean absolute Error 0.09845662790697672
# Mean Squared Error 0.017249048130232557
# Root Mean Squared Error 0.13133563160937156

# %%
score=cross_val_score(LR,X,Y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Differences between R2score and cv score',(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.84033754 0.89287839 0.85144394 0.92254711 0.75266229]
# 0.8519738557829587
# Differences between R2score and cv score 8.366620247903011

# %%
score=cross_val_score(RFR,X,Y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Differences between R2score and cv score',(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [0.85603406 0.92614941 0.93050884 0.9279614  0.74545026]
# 0.8772207941797104
# Differences between R2score and cv score 7.658114776282665

# %%
score=cross_val_score(knn,X,Y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Differences between R2score and cv score',(r2_score(y_test,pred_knn)-score.mean())*100)
# Out:
# [0.83948574 0.8748767  0.8491262  0.94312316 0.7443038 ]
# 0.8501831204240486
# Differences between R2score and cv score 10.507650857167782

# %%
score=cross_val_score(GBR,X,Y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Differences between R2score and cv score',(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [0.908714   0.96038519 0.93750857 0.93102835 0.80284709]
# 0.9080966387140922
# Differences between R2score and cv score 6.436716230690209

# %%
score=cross_val_score(lasso,X,Y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Differences between R2score and cv score',(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [-0.00643799 -0.0037979  -0.00364638 -0.00242138 -0.02411396]
# -0.008083520623131602
# Differences between R2score and cv score 0.6013874835529222

# %%
score=cross_val_score(rd,X,Y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Differences between R2score and cv score',(r2_score(y_test,pred_rd)-score.mean())*100)
# Out:
# [0.84054291 0.89286766 0.85174123 0.92274322 0.75292034]
# 0.8521630718743596
# Differences between R2score and cv score 8.377087821678874

# %%
score=cross_val_score(dtr,X,Y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Differences between R2score and cv score',(r2_score(y_test,pred_dtr)-score.mean())*100)
# Out:
# [0.72689452 0.78348645 0.8357318  0.7357702  0.55661319]
# 0.7276992330576405
# Differences between R2score and cv score 9.392696878690254

# %%
score=cross_val_score(svr,X,Y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Differences between R2score and cv score',(r2_score(y_test,pred_svr)-score.mean())*100)
# Out:
# [0.89331689 0.92360362 0.90131446 0.93755824 0.84096874]
# 0.8993523888979909
# Differences between R2score and cv score 6.329202096158204

# %%
score=cross_val_score(etr,X,Y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Differences between R2score and cv score',(r2_score(y_test,pred_etr)-score.mean())*100)
# Out:
# [0.8878136  0.94633797 0.93690295 0.9378047  0.79707943]
# 0.9011877300022025
# Differences between R2score and cv score 5.406327210520434

# %% [markdown]
# from the difference of both R2score and CV score computed on R2score . We can conclude that ExtraTreesRegressor as our best fitting and best performing model

# %%
 param={'n_estimators':[100],
        'criterion':['squared_error'], 
        'max_depth':[None], 
        'min_samples_split':[2],
        'min_samples_leaf':[1], 
        'min_weight_fraction_leaf':[0.0], 
        'max_features':[1.0], 
        'max_leaf_nodes':[None],
        'min_impurity_decrease':[0.0], 
        'bootstrap':[False], 
        'oob_score':[False], 
        'n_jobs':[None], 
        'random_state':[None], 
        'verbose':[0], 
        'warm_start':[False], 
        'ccp_alpha':[0.0], 
        'max_samples':[None]}

# %%
gscv=GridSearchCV(etr,param,cv=5)
gscv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'bootstrap': [False], 'ccp_alpha': [0.0],
#                          'criterion': ['squared_error'], 'max_depth': [None],
#                          'max_features': [1.0], 'max_leaf_nodes': [None],
#                          'max_samples': [None], 'min_impurity_decrease': [0.0],
#                          'min_samples_leaf': [1], 'min_samples_split': [2],
#                          'min_weight_fraction_leaf': [0.0],
#                          'n_estimators': [100], 'n_jobs': [None],
#                          'oob_score': [False], 'random_state': [None],
#                          'verbose': [0], 'warm_start': [False]})

# %%
gscv.best_params_
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
Model=ExtraTreesRegressor(bootstrap=False,
 ccp_alpha=0.0,
 criterion='squared_error',
 max_depth=None,
 max_features=1.0,
 max_leaf_nodes=None,
 max_samples=None,
 min_impurity_decrease=0.0,
 min_samples_leaf=1,
 min_samples_split=2,
 min_weight_fraction_leaf=0.0,
 n_estimators=100,
 n_jobs=None,
 oob_score=False,
 random_state=None,
 verbose=0,
 warm_start=False)

# %%
Model.fit(X_train, y_train)
pred=Model.predict(X_test)
print('R2_score',r2_score(y_test,pred))
print('Mean absolute Error',mean_absolute_error(y_test,pred))
print('Mean Squared Error',mean_squared_error(y_test,pred))
print('Root Mean Squared Error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score 0.9579112992437926
# Mean absolute Error 0.09455680232558136
# Mean Squared Error 0.016223604086627905
# Root Mean Squared Error 0.12737191247142324

# %% [markdown]
# # save model

# %%
import joblib
import pickle
filename='StudentGradePrediction.pkl'
pickle.dump(Model,open(filename,'wb'))

# %%
import pickle
loaded_model=pickle.load(open('StudentGradePrediction.pkl','rb'))
result=loaded_model.score(X_test,y_test)
print(result*100)
# Out:
# 95.79112992437926

# %%
conclusion=pd.DataFrame([loaded_model.predict(X_test)[:],(y_test)[:]],index=['predicted','original'])
conclusion
# Out:
#                0        1        2        3       4        5        6    \
# predicted  2.24615  3.48777  3.12503  2.57061  2.3829  3.71898  3.28227
# original   2.28800  3.56600  3.11400  2.38400  2.3110  3.70000  3.35000
#
#                7        8        9    ...      162      163      164      165  \
# predicted  3.90209  3.38535  3.80749  ...  2.57819  2.55305  2.93938  2.84217
# original   3.94300  3.44300  3.90800  ...  2.56400  2.48400  2.91700  2.78200
#
#                166      167     168      169      170      171
# predicted  2.42756  2.17936  3.5527  2.91158  2.25425  3.60344
# original   2.32100  2.18800  3.5540  3.05800  2.08700  3.64700
#
# [2 rows x 172 columns]

# %%
plt.figure(figsize=(8,5))
plt.scatter(x=pred_LR,y=y_test,color='r')
plt.plot(pred_LR,pred_LR,color='b')
plt.xlabel('Actual')
plt.ylabel('predicted')
plt.title('Linear Regression')
plt.show()
