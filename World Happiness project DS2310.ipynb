# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# there are 3 different data sets int,float,object

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# this gives brief information about the dataset which includes indexing type,column type,no null values and memoryusage
# maximum dataset contain float type

# %%
#visualise by use heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# visualise there is no missing data present in the given dataset

# %%
df.nunique().to_frame('No.of unique values')
# Out:
#                                No.of unique values
# Country                                        158
# Region                                          10
# Happiness Rank                                 157
# Happiness Score                                157
# Standard Error                                 153
# Economy (GDP per Capita)                       158
# Family                                         158
# Health (Life Expectancy)                       157
# Freedom                                        158
# Trust (Government Corruption)                  157
# Generosity                                     158
# Dystopia Residual                              158

# %% [markdown]
# it gives all are unique values present in the given dataset

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
Index=0
labels = df['Happiness Score']
features = df.drop('Happiness Score', axis=1)

for col in features.items():
    plt.figure(figsize=(2,3))
    sns.barplot(x=labels, y=col[Index], data=df, palette='husl')
plt.tight_layout()
plt.show()

# %%
Index=0
labels = df['Happiness Score']
features = df.drop('Happiness Score', axis=1)

for col in features.items():
    plt.figure(figsize=(2,3))
    sns.scatterplot(x=labels, y=col[Index], data=df, color="red")
plt.tight_layout()
plt.show()

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
plt.figure()
sns.heatmap(df.corr(),annot=True)
plt.xlabel('Figure')
plt.ylabel('Features_Name')
plt.title('Discriptive_Graph')
plt.show()

# %% [markdown]
# Above  graph are showing us how is the correlation between each variable, we will concentrate the highly correlated variables. Happiness Rank and Happiness Score have negative correlation, while Happiness Score is increasing, Ranking is going to decrease (1 is the top, 158 is the last ranking). Therefore, we will analyze Happiness Score relations with GDP, Life Expectations, Freedom and Trust to Government Corruption as these values are highly correlated to each other. GDP is the main factor which is effecting others as Family, Life Expectations and Freedom.

# %%
sns.pairplot(df, hue=None, kind="reg")

# %% [markdown]
# Scatterplots show relationships between two variables. I wanted to see each variable positive and negative relationships, uphill lines are showing positive, downhill lines are negative relationships. In above plots are showing that we have weaker, stronger relationships.

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# gives range +/- 0.5 give information about outliers

# %% [markdown]
# # final conclusion

# %%
plt.figure(figsize=(2,3))
plt.title('Economy (GDP per Capita) vs Happiness Score')
sns.barplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df,palette='Blues')
# Out:
# <Axes: title={'center': 'Economy (GDP per Capita) vs Happiness Score'}, xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
plt.figure(figsize=(2,3))
plt.title('Family vs Happiness Score')
sns.barplot(x='Family',y='Happiness Score',data=df,palette='Blues')
# Out:
# <Axes: title={'center': 'Family vs Happiness Score'}, xlabel='Family', ylabel='Happiness Score'>

# %%
plt.figure(figsize=(2,3))
plt.title('Health (Life Expectancy) vs Happiness Score')
sns.barplot(x='Health (Life Expectancy)',y='Happiness Score',data=df)
# Out:
# <Axes: title={'center': 'Health (Life Expectancy) vs Happiness Score'}, xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %%
plt.figure(figsize=(2,3))
plt.title('Freedom vs Happiness Score')
sns.barplot(x='Freedom',y='Happiness Score',data=df,palette='Blues')
# Out:
# <Axes: title={'center': 'Freedom vs Happiness Score'}, xlabel='Freedom', ylabel='Happiness Score'>

# %%
plt.figure(figsize=(2,3))
plt.title('Trust (Government Corruption) vs Happiness Score')
sns.barplot(x='Trust (Government Corruption)',y='Happiness Score',data=df,palette='Blues')
# Out:
# <Axes: title={'center': 'Trust (Government Corruption) vs Happiness Score'}, xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %%
plt.figure(figsize=(2,3))
plt.title('Economy (GDP per Capita) vs Happiness Score')
sns.regplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df)
# Out:
# <Axes: title={'center': 'Economy (GDP per Capita) vs Happiness Score'}, xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
plt.figure(figsize=(2,3))
plt.title('Family vs Happiness Score')
sns.regplot(x='Family',y='Happiness Score',data=df)
# Out:
# <Axes: title={'center': 'Family vs Happiness Score'}, xlabel='Family', ylabel='Happiness Score'>

# %%
plt.figure(figsize=(2,3))
plt.title('Health (Life Expectancy) vs Happiness Score')
sns.regplot(x='Health (Life Expectancy)',y='Happiness Score',data=df)
# Out:
# <Axes: title={'center': 'Health (Life Expectancy) vs Happiness Score'}, xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %%
plt.figure(figsize=(2,3))
plt.title('Freedom vs Happiness Score')
sns.regplot(x='Freedom',y='Happiness Score',data=df)
# Out:
# <Axes: title={'center': 'Freedom vs Happiness Score'}, xlabel='Freedom', ylabel='Happiness Score'>

# %%
plt.figure(figsize=(2,3))
plt.title('Trust (Government Corruption) vs Happiness Score')
sns.regplot(x='Trust (Government Corruption)',y='Happiness Score',data=df)
# Out:
# <Axes: title={'center': 'Trust (Government Corruption) vs Happiness Score'}, xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %%
df1= df.groupby(['Region','Trust (Government Corruption)','Family','Economy (GDP per Capita)','Health (Life Expectancy)','Freedom'], sort=False)['Happiness Score'].max().head(10) #I wanted to see top 10 Happy Countries
df1
# Out:
# Region                     Trust (Government Corruption)  Family   Economy (GDP per Capita)  Health (Life Expectancy)  Freedom
# Western Europe             0.41978                        1.34951  1.39651                   0.94143                   0.66557    7.587
#                            0.14145                        1.40223  1.30232                   0.94784                   0.62877    7.561
#                            0.48357                        1.36058  1.32548                   0.87464                   0.64938    7.527
#                            0.36503                        1.33095  1.45900                   0.88521                   0.66973    7.522
# North America              0.32957                        1.32261  1.32629                   0.90563                   0.63297    7.427
# Western Europe             0.41372                        1.31826  1.29025                   0.88911                   0.64169    7.406
# ...
